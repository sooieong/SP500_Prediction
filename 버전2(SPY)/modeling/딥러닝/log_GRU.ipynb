# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# ===============================
# 0. 시드 고정 (재현성)
# ===============================
SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# ===============================
# 1. 데이터 로드
# ===============================
df = pd.read_csv('../../preprocessing/log공선성제거_Final_data.csv')
df["ret_prev"] = (df["y_target_log"] - df["y_target_log"].shift(1))

# Date 컬럼
date_col = "Date"

# y_target 컬럼 (타깃)
target_col = "ret_prev"

df[date_col] = pd.to_datetime(df[date_col])

# 숫자형만 사용 + 결측 제거
df_num = df.select_dtypes(include=[np.number]).dropna()

# 숫자행에 맞는 날짜만 따로 정렬 (인덱스 맞추기용)
dates_num = df.loc[df_num.index, date_col].reset_index(drop=True)

# X: y_target 제외
feature_cols = [c for c in df_num.columns if c != target_col or 'y_target_log']
X_raw = df_num[feature_cols].values        # (N, num_features)
y_raw = df_num[[target_col]].values       # (N, 1)

print("X_raw shape:", X_raw.shape)
print("y_raw shape:", y_raw.shape)
# Out:
# X_raw shape: (753, 7)
# y_raw shape: (753, 1)

# %%
# ===============================
# 2. 스케일링 (X / y 따로)
# ===============================
# NOTE: 현재는 전체 구간 기준으로 fit_transform 함.
scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X_raw)

scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y_raw)

# ===============================
# 3. 시계열 데이터셋 생성 함수
# ===============================
def make_dataset(X_arr, y_arr, seq_len):
    Xs, ys = [], []
    for i in range(len(X_arr) - seq_len):
        Xs.append(X_arr[i:i+seq_len])      # (seq_len, num_features)
        ys.append(y_arr[i+seq_len])        # (1,)
    return np.array(Xs), np.array(ys)

# ===============================
# 4. 모델 정의 (GRU only)
# ===============================
def build_model(seq_len, num_features):
    inputs = Input(shape=(seq_len, num_features))

    # GRU 스택
    x = LSTM(64, return_sequences=True)(inputs)

    outputs = Dense(1)(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(0.001),
        loss='mse',
        metrics=['mae']
    )
    return model

# %%
# ===============================
# 5. seq_len 후보 [5,15,30,60,90] 중 최적 선택 (val_loss 기준)
# ===============================
candidate_seq_lens = list(range(1, 51))


best_seq_len  = None
best_val_loss = np.inf

for seq_len in candidate_seq_lens:
    # 1) 시퀀스 데이터 생성
    X_tmp, y_tmp = make_dataset(X_scaled, y_scaled, seq_len)
    n_samples = len(X_tmp)

    if n_samples < 10:
        print(f"seq_len={seq_len} → 샘플 수 부족 (n={n_samples}), 스킵")
        continue

    # 2) Train / Val / Test 분할 
    test_size = int(n_samples * 0.20)
    remaining = n_samples - test_size
    val_size = int(remaining * 0.20)
    train_size = remaining - val_size
    val_end    = train_size + val_size
    train_end  = train_size

    X_train_tmp = X_tmp[:train_end]
    y_train_tmp = y_tmp[:train_end]

    X_val_tmp   = X_tmp[train_end:val_end]
    y_val_tmp   = y_tmp[train_end:val_end]

    # 3) 임시 모델 생성
    model_tmp = build_model(seq_len, X_tmp.shape[2])

    early_tmp = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )

    # 4) 학습
    history_tmp = model_tmp.fit(
        X_train_tmp, y_train_tmp,
        validation_data=(X_val_tmp, y_val_tmp),
        epochs=200,
        batch_size=64,
        callbacks=[early_tmp],
        verbose=0,
        shuffle=False,     # 시계열이니 섞지 않음
    )

    # 5) 최소 val_loss
    val_loss = min(history_tmp.history["val_loss"])
    print(f"seq_len={seq_len} → best val_loss={val_loss:.6f}")

    # 6) 최적 seq_len 갱신
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_seq_len  = seq_len

# ==============================
# ✅ 여기부터 “데이터 개수 확인” 추가
# ==============================
print(f"\n최적 seq_len = {best_seq_len}, best val_loss = {best_val_loss:.6f}")
# Out:
# seq_len=1 → best val_loss=0.007406
# seq_len=2 → best val_loss=0.005176
# seq_len=3 → best val_loss=0.005233
# seq_len=4 → best val_loss=0.005300
# seq_len=5 → best val_loss=0.005331
# seq_len=6 → best val_loss=0.005507
# seq_len=7 → best val_loss=0.005126
# seq_len=8 → best val_loss=0.005449
# seq_len=9 → best val_loss=0.005506
# seq_len=10 → best val_loss=0.005273
# seq_len=11 → best val_loss=0.005747
# seq_len=12 → best val_loss=0.005355
# seq_len=13 → best val_loss=0.005682
# seq_len=14 → best val_loss=0.008758
# seq_len=15 → best val_loss=0.008775
# seq_len=16 → best val_loss=0.008747
# seq_len=17 → best val_loss=0.008812
# seq_len=18 → best val_loss=0.008796
# seq_len=19 → best val_loss=0.009481
# seq_len=20 → best val_loss=0.009605
# seq_len=21 → best val_loss=0.009486
# seq_len=22 → best val_loss=0.009488
# seq_len=23 → best val_loss=0.009483
# seq_len=24 → best val_loss=0.009711
# seq_len=25 → best val_loss=0.009643
# seq_len=26 → best val_loss=0.009610
# seq_len=27 → best val_loss=0.009707
# seq_len=28 → best val_loss=0.009611
# seq_len=29 → best val_loss=0.009605
# seq_len=30 → best val_loss=0.009796
# seq_len=31 → best val_loss=0.009732
# seq_len=32 → best val_loss=0.009773
# seq_len=33 → best val_loss=0.009754
# seq_len=34 → best val_loss=0.009757
# seq_len=35 → best val_loss=0.009723
# seq_len=36 → best val_loss=0.009810
# seq_len=37 → best val_loss=0.009811
# seq_len=38 → best val_loss=0.009892
# seq_len=39 → best val_loss=0.009940
# seq_len=40 → best val_loss=0.010007
# seq_len=41 → best val_loss=0.010009
# seq_len=42 → best val_loss=0.010041
# seq_len=43 → best val_loss=0.010010
# seq_len=44 → best val_loss=0.009925
# seq_len=45 → best val_loss=0.009909
# seq_len=46 → best val_loss=0.009955
# seq_len=47 → best val_loss=0.010238
# seq_len=48 → best val_loss=0.010217
# seq_len=49 → best val_loss=0.010243
# seq_len=50 → best val_loss=0.010098
#
# 최적 seq_len = 7, best val_loss = 0.005126

# %%
# 최적 seq_len으로 다시 시퀀스 생성
X_best, y_best = make_dataset(X_scaled, y_scaled, best_seq_len)
n_samples = len(X_best)

train_size = int(n_samples * 0.6)
val_size   = int(n_samples * 0.2)
test_size  = n_samples - train_size - val_size  # 나머지

print(f"전체 샘플 수 (n_samples): {n_samples}")
print(f"train 샘플 수          : {train_size}")
print(f"val 샘플 수            : {val_size}")
print(f"test(남는 구간) 샘플 수 : {test_size}")

print("X_best shape:", X_best.shape)
print("y_best shape:", y_best.shape)
# Out:
# 전체 샘플 수 (n_samples): 746
# train 샘플 수          : 447
# val 샘플 수            : 149
# test(남는 구간) 샘플 수 : 150
# X_best shape: (746, 7, 7)
# y_best shape: (746, 1)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# ===============================
# 7. 최종 모델 정의 및 학습 + 최적 모델 저장
# ===============================

# 🔹 위에서 찾은 best_seq_len을 최종 SEQ_LEN으로 사용한다고 가정
SEQ_LEN = best_seq_len  

# 🔹 X_best, y_best를 train/val/test로 나누는 코드가 있어야 합니다
# (이미 나눠두셨다면 이 부분은 생략하고 기존 X_train, y_train 등을 쓰면 됩니다)
X_train = X_best[:train_size]
y_train = y_best[:train_size]

X_val   = X_best[train_size:train_size+val_size]
y_val   = y_best[train_size:train_size+val_size]

X_test  = X_best[train_size+val_size:]
y_test  = y_best[train_size+val_size:]

# 🔹 최종 모델 생성
model = build_model(SEQ_LEN, X_train.shape[2])
model.summary()

# 🔹 EarlyStopping (가장 좋은 weight로 복원)
early = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# 🔹 ModelCheckpoint: val_loss가 갱신될 때만 모델 저장
checkpoint_path = "../../modeling/Model/GRU_best.keras"  # 저장 경로 원하는 대로 수정
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor='val_loss',
    save_best_only=True,   # 가장 좋은 모델만 저장
    save_weights_only=False,  # 전체 모델(구조+가중치) 저장
    mode='min',
    verbose=1
)

# 🔹 학습: 콜백에 EarlyStopping + Checkpoint 둘 다 넣기
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=500,
    batch_size=64,
    # callbacks=[early, checkpoint],   # ✅ 여기!
    callbacks=[checkpoint], 
    verbose=1,
    shuffle=False,                   # 시계열이니 섞지 않음
)
# Out:
# Model: "functional_57"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_57 (InputLayer)     │ (None, 7, 7)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_57 (LSTM)                  │ (None, 7, 64)          │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 7, 1)           │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,497 (72.25 KB)
#  Trainable params: 18,497 (72.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 0.1330 - mae: 0.3575
# Epoch 1: val_loss improved from None to 0.02680, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 0.0700 - mae: 0.2379 - val_loss: 0.0268 - val_mae: 0.1360
# Epoch 2/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0376 - mae: 0.1618
# Epoch 2: val_loss did not improve from 0.02680
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0332 - mae: 0.1510 - val_loss: 0.0632 - val_mae: 0.2129
# Epoch 3/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0283 - mae: 0.1388
# Epoch 3: val_loss did not improve from 0.02680
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0252 - mae: 0.1332 - val_loss: 0.0333 - val_mae: 0.1546
# Epoch 4/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0235 - mae: 0.1221
# Epoch 4: val_loss improved from 0.02680 to 0.01869, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0185 - mae: 0.1066 - val_loss: 0.0187 - val_mae: 0.1106
# Epoch 5/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0238 - mae: 0.1239
# Epoch 5: val_loss improved from 0.01869 to 0.01614, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0176 - mae: 0.1027 - val_loss: 0.0161 - val_mae: 0.1010
# Epoch 6/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0212 - mae: 0.1162
# Epoch 6: val_loss did not improve from 0.01614
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0151 - mae: 0.0949 - val_loss: 0.0173 - val_mae: 0.1075
# Epoch 7/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0173 - mae: 0.1032
# Epoch 7: val_loss did not improve from 0.01614
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0129 - mae: 0.0878 - val_loss: 0.0174 - val_mae: 0.1082
# Epoch 8/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0152 - mae: 0.0963
# Epoch 8: val_loss improved from 0.01614 to 0.01395, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0111 - mae: 0.0806 - val_loss: 0.0140 - val_mae: 0.0940
# Epoch 9/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0139 - mae: 0.0917
# Epoch 9: val_loss improved from 0.01395 to 0.01102, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0097 - mae: 0.0739 - val_loss: 0.0110 - val_mae: 0.0791
# Epoch 10/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0129 - mae: 0.0886
# Epoch 10: val_loss improved from 0.01102 to 0.01012, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0088 - mae: 0.0703 - val_loss: 0.0101 - val_mae: 0.0743
# Epoch 11/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0118 - mae: 0.0847
# Epoch 11: val_loss improved from 0.01012 to 0.01011, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0079 - mae: 0.0670 - val_loss: 0.0101 - val_mae: 0.0746
# Epoch 12/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0108 - mae: 0.0813
# Epoch 12: val_loss improved from 0.01011 to 0.00972, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0073 - mae: 0.0646 - val_loss: 0.0097 - val_mae: 0.0729
# Epoch 13/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0102 - mae: 0.0793
# Epoch 13: val_loss improved from 0.00972 to 0.00929, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0068 - mae: 0.0631 - val_loss: 0.0093 - val_mae: 0.0711
# Epoch 14/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0098 - mae: 0.0779
# Epoch 14: val_loss improved from 0.00929 to 0.00925, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0065 - mae: 0.0620 - val_loss: 0.0093 - val_mae: 0.0711
# Epoch 15/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0094 - mae: 0.0766
# Epoch 15: val_loss improved from 0.00925 to 0.00917, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0062 - mae: 0.0608 - val_loss: 0.0092 - val_mae: 0.0708
# Epoch 16/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0091 - mae: 0.0755
# Epoch 16: val_loss improved from 0.00917 to 0.00886, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0060 - mae: 0.0597 - val_loss: 0.0089 - val_mae: 0.0692
# Epoch 17/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0089 - mae: 0.0745
# Epoch 17: val_loss improved from 0.00886 to 0.00860, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0057 - mae: 0.0585 - val_loss: 0.0086 - val_mae: 0.0678
# Epoch 18/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0086 - mae: 0.0736
# Epoch 18: val_loss improved from 0.00860 to 0.00840, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0055 - mae: 0.0575 - val_loss: 0.0084 - val_mae: 0.0666
# Epoch 19/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0084 - mae: 0.0728
# Epoch 19: val_loss improved from 0.00840 to 0.00814, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0053 - mae: 0.0564 - val_loss: 0.0081 - val_mae: 0.0652
# Epoch 20/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0082 - mae: 0.0720
# Epoch 20: val_loss improved from 0.00814 to 0.00789, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0051 - mae: 0.0554 - val_loss: 0.0079 - val_mae: 0.0638
# Epoch 21/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0080 - mae: 0.0712
# Epoch 21: val_loss improved from 0.00789 to 0.00767, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0049 - mae: 0.0545 - val_loss: 0.0077 - val_mae: 0.0625
# Epoch 22/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0078 - mae: 0.0705
# Epoch 22: val_loss improved from 0.00767 to 0.00745, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0048 - mae: 0.0535 - val_loss: 0.0075 - val_mae: 0.0612
# Epoch 23/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0076 - mae: 0.0697
# Epoch 23: val_loss improved from 0.00745 to 0.00724, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0046 - mae: 0.0527 - val_loss: 0.0072 - val_mae: 0.0599
# Epoch 24/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0075 - mae: 0.0691
# Epoch 24: val_loss improved from 0.00724 to 0.00705, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0045 - mae: 0.0518 - val_loss: 0.0070 - val_mae: 0.0587
# Epoch 25/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0073 - mae: 0.0685
# Epoch 25: val_loss improved from 0.00705 to 0.00687, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0043 - mae: 0.0510 - val_loss: 0.0069 - val_mae: 0.0576
# Epoch 26/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0072 - mae: 0.0679
# Epoch 26: val_loss improved from 0.00687 to 0.00670, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0042 - mae: 0.0502 - val_loss: 0.0067 - val_mae: 0.0566
# Epoch 27/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0070 - mae: 0.0673
# Epoch 27: val_loss improved from 0.00670 to 0.00654, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0041 - mae: 0.0495 - val_loss: 0.0065 - val_mae: 0.0556
# Epoch 28/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0069 - mae: 0.0668
# Epoch 28: val_loss improved from 0.00654 to 0.00640, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0040 - mae: 0.0488 - val_loss: 0.0064 - val_mae: 0.0548
# Epoch 29/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0068 - mae: 0.0664
# Epoch 29: val_loss improved from 0.00640 to 0.00627, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0039 - mae: 0.0482 - val_loss: 0.0063 - val_mae: 0.0540
# Epoch 30/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0067 - mae: 0.0660
# Epoch 30: val_loss improved from 0.00627 to 0.00615, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0038 - mae: 0.0476 - val_loss: 0.0062 - val_mae: 0.0534
# Epoch 31/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0066 - mae: 0.0656
# Epoch 31: val_loss improved from 0.00615 to 0.00605, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0037 - mae: 0.0471 - val_loss: 0.0061 - val_mae: 0.0528
# Epoch 32/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0065 - mae: 0.0652
# Epoch 32: val_loss improved from 0.00605 to 0.00596, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0036 - mae: 0.0466 - val_loss: 0.0060 - val_mae: 0.0523
# Epoch 33/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0064 - mae: 0.0648
# Epoch 33: val_loss improved from 0.00596 to 0.00588, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0036 - mae: 0.0462 - val_loss: 0.0059 - val_mae: 0.0519
# Epoch 34/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0064 - mae: 0.0646
# Epoch 34: val_loss improved from 0.00588 to 0.00581, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0035 - mae: 0.0459 - val_loss: 0.0058 - val_mae: 0.0516
# Epoch 35/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0063 - mae: 0.0644
# Epoch 35: val_loss improved from 0.00581 to 0.00576, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0035 - mae: 0.0455 - val_loss: 0.0058 - val_mae: 0.0513
# Epoch 36/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0063 - mae: 0.0642
# Epoch 36: val_loss improved from 0.00576 to 0.00571, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0034 - mae: 0.0453 - val_loss: 0.0057 - val_mae: 0.0511
# Epoch 37/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0062 - mae: 0.0640
# Epoch 37: val_loss improved from 0.00571 to 0.00567, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0034 - mae: 0.0450 - val_loss: 0.0057 - val_mae: 0.0509
# Epoch 38/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0062 - mae: 0.0638
# Epoch 38: val_loss improved from 0.00567 to 0.00563, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0034 - mae: 0.0448 - val_loss: 0.0056 - val_mae: 0.0508
# Epoch 39/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0061 - mae: 0.0636
# Epoch 39: val_loss improved from 0.00563 to 0.00560, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0033 - mae: 0.0447 - val_loss: 0.0056 - val_mae: 0.0507
# Epoch 40/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0061 - mae: 0.0635
# Epoch 40: val_loss improved from 0.00560 to 0.00558, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0033 - mae: 0.0445 - val_loss: 0.0056 - val_mae: 0.0506
# Epoch 41/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0061 - mae: 0.0633
# Epoch 41: val_loss improved from 0.00558 to 0.00556, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0033 - mae: 0.0444 - val_loss: 0.0056 - val_mae: 0.0505
# Epoch 42/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0060 - mae: 0.0632
# Epoch 42: val_loss improved from 0.00556 to 0.00554, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0033 - mae: 0.0442 - val_loss: 0.0055 - val_mae: 0.0504
# Epoch 43/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0060 - mae: 0.0630
# Epoch 43: val_loss improved from 0.00554 to 0.00552, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0032 - mae: 0.0441 - val_loss: 0.0055 - val_mae: 0.0503
# Epoch 44/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0060 - mae: 0.0629
# Epoch 44: val_loss improved from 0.00552 to 0.00550, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0032 - mae: 0.0440 - val_loss: 0.0055 - val_mae: 0.0503
# Epoch 45/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0060 - mae: 0.0628
# Epoch 45: val_loss improved from 0.00550 to 0.00548, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0032 - mae: 0.0439 - val_loss: 0.0055 - val_mae: 0.0502
# Epoch 46/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0059 - mae: 0.0626
# Epoch 46: val_loss improved from 0.00548 to 0.00546, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0032 - mae: 0.0438 - val_loss: 0.0055 - val_mae: 0.0502
# Epoch 47/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0059 - mae: 0.0625
# Epoch 47: val_loss improved from 0.00546 to 0.00545, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0032 - mae: 0.0437 - val_loss: 0.0054 - val_mae: 0.0501
# Epoch 48/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0059 - mae: 0.0624
# Epoch 48: val_loss improved from 0.00545 to 0.00543, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0032 - mae: 0.0436 - val_loss: 0.0054 - val_mae: 0.0500
# Epoch 49/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0059 - mae: 0.0623
# Epoch 49: val_loss improved from 0.00543 to 0.00542, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0032 - mae: 0.0435 - val_loss: 0.0054 - val_mae: 0.0500
# Epoch 50/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0059 - mae: 0.0622
# Epoch 50: val_loss improved from 0.00542 to 0.00540, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0032 - mae: 0.0434 - val_loss: 0.0054 - val_mae: 0.0499
# Epoch 51/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0058 - mae: 0.0621
# Epoch 51: val_loss improved from 0.00540 to 0.00539, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0434 - val_loss: 0.0054 - val_mae: 0.0499
# Epoch 52/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0058 - mae: 0.0620
# Epoch 52: val_loss improved from 0.00539 to 0.00538, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0433 - val_loss: 0.0054 - val_mae: 0.0498
# Epoch 53/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0058 - mae: 0.0619
# Epoch 53: val_loss improved from 0.00538 to 0.00537, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031 - mae: 0.0432 - val_loss: 0.0054 - val_mae: 0.0498
# Epoch 54/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0058 - mae: 0.0618
# Epoch 54: val_loss improved from 0.00537 to 0.00535, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0431 - val_loss: 0.0054 - val_mae: 0.0497
# Epoch 55/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0058 - mae: 0.0617
# Epoch 55: val_loss improved from 0.00535 to 0.00534, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0431 - val_loss: 0.0053 - val_mae: 0.0497
# Epoch 56/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0058 - mae: 0.0616
# Epoch 56: val_loss improved from 0.00534 to 0.00533, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0430 - val_loss: 0.0053 - val_mae: 0.0496
# Epoch 57/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0058 - mae: 0.0616
# Epoch 57: val_loss improved from 0.00533 to 0.00532, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0429 - val_loss: 0.0053 - val_mae: 0.0495
# Epoch 58/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0057 - mae: 0.0615
# Epoch 58: val_loss improved from 0.00532 to 0.00531, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0429 - val_loss: 0.0053 - val_mae: 0.0495
# Epoch 59/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0057 - mae: 0.0614
# Epoch 59: val_loss improved from 0.00531 to 0.00530, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0428 - val_loss: 0.0053 - val_mae: 0.0494
# Epoch 60/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0057 - mae: 0.0613
# Epoch 60: val_loss improved from 0.00530 to 0.00529, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0428 - val_loss: 0.0053 - val_mae: 0.0494
# Epoch 61/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0057 - mae: 0.0613
# Epoch 61: val_loss improved from 0.00529 to 0.00528, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0427 - val_loss: 0.0053 - val_mae: 0.0493
# Epoch 62/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0057 - mae: 0.0612
# Epoch 62: val_loss improved from 0.00528 to 0.00527, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031 - mae: 0.0427 - val_loss: 0.0053 - val_mae: 0.0493
# Epoch 63/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.0057 - mae: 0.0611
# Epoch 63: val_loss improved from 0.00527 to 0.00526, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0426 - val_loss: 0.0053 - val_mae: 0.0492
# Epoch 64/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0057 - mae: 0.0610
# Epoch 64: val_loss improved from 0.00526 to 0.00525, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - mae: 0.0426 - val_loss: 0.0052 - val_mae: 0.0492
# Epoch 65/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0057 - mae: 0.0610
# Epoch 65: val_loss improved from 0.00525 to 0.00524, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0030 - mae: 0.0425 - val_loss: 0.0052 - val_mae: 0.0491
# Epoch 66/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0056 - mae: 0.0609
# Epoch 66: val_loss improved from 0.00524 to 0.00523, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - mae: 0.0425 - val_loss: 0.0052 - val_mae: 0.0491
# Epoch 67/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0056 - mae: 0.0608
# Epoch 67: val_loss improved from 0.00523 to 0.00522, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - mae: 0.0424 - val_loss: 0.0052 - val_mae: 0.0490
# Epoch 68/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0056 - mae: 0.0608
# Epoch 68: val_loss improved from 0.00522 to 0.00521, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0030 - mae: 0.0424 - val_loss: 0.0052 - val_mae: 0.0490
# Epoch 69/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0056 - mae: 0.0607
# Epoch 69: val_loss improved from 0.00521 to 0.00520, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - mae: 0.0423 - val_loss: 0.0052 - val_mae: 0.0489
# Epoch 70/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0056 - mae: 0.0607
# Epoch 70: val_loss improved from 0.00520 to 0.00520, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0030 - mae: 0.0423 - val_loss: 0.0052 - val_mae: 0.0489
# Epoch 71/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0056 - mae: 0.0606
# Epoch 71: val_loss improved from 0.00520 to 0.00519, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0030 - mae: 0.0423 - val_loss: 0.0052 - val_mae: 0.0488
# Epoch 72/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0056 - mae: 0.0606
# Epoch 72: val_loss improved from 0.00519 to 0.00518, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0030 - mae: 0.0422 - val_loss: 0.0052 - val_mae: 0.0488
# Epoch 73/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0056 - mae: 0.0605
# Epoch 73: val_loss improved from 0.00518 to 0.00517, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0030 - mae: 0.0422 - val_loss: 0.0052 - val_mae: 0.0488
# Epoch 74/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0056 - mae: 0.0605
# Epoch 74: val_loss improved from 0.00517 to 0.00517, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0030 - mae: 0.0422 - val_loss: 0.0052 - val_mae: 0.0487
# Epoch 75/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0056 - mae: 0.0604
# Epoch 75: val_loss improved from 0.00517 to 0.00516, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0030 - mae: 0.0421 - val_loss: 0.0052 - val_mae: 0.0487
# Epoch 76/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0056 - mae: 0.0604
# Epoch 76: val_loss improved from 0.00516 to 0.00515, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0030 - mae: 0.0421 - val_loss: 0.0052 - val_mae: 0.0486
# Epoch 77/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0056 - mae: 0.0603
# Epoch 77: val_loss improved from 0.00515 to 0.00515, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - mae: 0.0421 - val_loss: 0.0051 - val_mae: 0.0486
# Epoch 78/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0055 - mae: 0.0603
# Epoch 78: val_loss improved from 0.00515 to 0.00514, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - mae: 0.0420 - val_loss: 0.0051 - val_mae: 0.0486
# Epoch 79/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0055 - mae: 0.0602
# Epoch 79: val_loss improved from 0.00514 to 0.00513, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - mae: 0.0420 - val_loss: 0.0051 - val_mae: 0.0485
# Epoch 80/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0055 - mae: 0.0602
# Epoch 80: val_loss improved from 0.00513 to 0.00513, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - mae: 0.0420 - val_loss: 0.0051 - val_mae: 0.0485
# Epoch 81/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0055 - mae: 0.0601
# Epoch 81: val_loss improved from 0.00513 to 0.00512, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - mae: 0.0419 - val_loss: 0.0051 - val_mae: 0.0484
# Epoch 82/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0055 - mae: 0.0601
# Epoch 82: val_loss improved from 0.00512 to 0.00511, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0030 - mae: 0.0419 - val_loss: 0.0051 - val_mae: 0.0484
# Epoch 83/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0055 - mae: 0.0600
# Epoch 83: val_loss improved from 0.00511 to 0.00511, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0030 - mae: 0.0419 - val_loss: 0.0051 - val_mae: 0.0484
# Epoch 84/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0055 - mae: 0.0600
# Epoch 84: val_loss improved from 0.00511 to 0.00510, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0030 - mae: 0.0419 - val_loss: 0.0051 - val_mae: 0.0483
# Epoch 85/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0055 - mae: 0.0600
# Epoch 85: val_loss improved from 0.00510 to 0.00510, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0030 - mae: 0.0418 - val_loss: 0.0051 - val_mae: 0.0483
# Epoch 86/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0055 - mae: 0.0599
# Epoch 86: val_loss improved from 0.00510 to 0.00509, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0030 - mae: 0.0418 - val_loss: 0.0051 - val_mae: 0.0483
# Epoch 87/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0055 - mae: 0.0599
# Epoch 87: val_loss improved from 0.00509 to 0.00509, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0418 - val_loss: 0.0051 - val_mae: 0.0482
# Epoch 88/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0055 - mae: 0.0598
# Epoch 88: val_loss improved from 0.00509 to 0.00508, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0417 - val_loss: 0.0051 - val_mae: 0.0482
# Epoch 89/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0055 - mae: 0.0598
# Epoch 89: val_loss improved from 0.00508 to 0.00508, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0417 - val_loss: 0.0051 - val_mae: 0.0482
# Epoch 90/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0055 - mae: 0.0598
# Epoch 90: val_loss improved from 0.00508 to 0.00507, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0417 - val_loss: 0.0051 - val_mae: 0.0482
# Epoch 91/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0055 - mae: 0.0597
# Epoch 91: val_loss improved from 0.00507 to 0.00507, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0417 - val_loss: 0.0051 - val_mae: 0.0481
# Epoch 92/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0054 - mae: 0.0597
# Epoch 92: val_loss improved from 0.00507 to 0.00506, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - mae: 0.0417 - val_loss: 0.0051 - val_mae: 0.0481
# Epoch 93/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0054 - mae: 0.0596
# Epoch 93: val_loss improved from 0.00506 to 0.00506, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0416 - val_loss: 0.0051 - val_mae: 0.0481
# Epoch 94/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0054 - mae: 0.0596
# Epoch 94: val_loss improved from 0.00506 to 0.00505, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0416 - val_loss: 0.0051 - val_mae: 0.0480
# Epoch 95/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0054 - mae: 0.0596
# Epoch 95: val_loss improved from 0.00505 to 0.00505, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0416 - val_loss: 0.0050 - val_mae: 0.0480
# Epoch 96/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0054 - mae: 0.0595
# Epoch 96: val_loss improved from 0.00505 to 0.00505, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - mae: 0.0416 - val_loss: 0.0050 - val_mae: 0.0480
# Epoch 97/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0054 - mae: 0.0595
# Epoch 97: val_loss improved from 0.00505 to 0.00504, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0415 - val_loss: 0.0050 - val_mae: 0.0480
# Epoch 98/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0054 - mae: 0.0595
# Epoch 98: val_loss improved from 0.00504 to 0.00504, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0415 - val_loss: 0.0050 - val_mae: 0.0479
# Epoch 99/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0054 - mae: 0.0594
# Epoch 99: val_loss improved from 0.00504 to 0.00503, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0415 - val_loss: 0.0050 - val_mae: 0.0479
# Epoch 100/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0054 - mae: 0.0594
# Epoch 100: val_loss improved from 0.00503 to 0.00503, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0415 - val_loss: 0.0050 - val_mae: 0.0479
# Epoch 101/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0054 - mae: 0.0594
# Epoch 101: val_loss improved from 0.00503 to 0.00503, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0415 - val_loss: 0.0050 - val_mae: 0.0479
# Epoch 102/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0054 - mae: 0.0594
# Epoch 102: val_loss improved from 0.00503 to 0.00502, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0415 - val_loss: 0.0050 - val_mae: 0.0478
# Epoch 103/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0054 - mae: 0.0593
# Epoch 103: val_loss improved from 0.00502 to 0.00502, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - mae: 0.0414 - val_loss: 0.0050 - val_mae: 0.0478
# Epoch 104/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0054 - mae: 0.0593
# Epoch 104: val_loss improved from 0.00502 to 0.00502, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0414 - val_loss: 0.0050 - val_mae: 0.0478
# Epoch 105/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0054 - mae: 0.0593
# Epoch 105: val_loss improved from 0.00502 to 0.00501, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0414 - val_loss: 0.0050 - val_mae: 0.0478
# Epoch 106/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0054 - mae: 0.0592
# Epoch 106: val_loss improved from 0.00501 to 0.00501, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0029 - mae: 0.0414 - val_loss: 0.0050 - val_mae: 0.0477
# Epoch 107/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0054 - mae: 0.0592
# Epoch 107: val_loss improved from 0.00501 to 0.00501, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0414 - val_loss: 0.0050 - val_mae: 0.0477
# Epoch 108/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0054 - mae: 0.0592
# Epoch 108: val_loss improved from 0.00501 to 0.00500, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0414 - val_loss: 0.0050 - val_mae: 0.0477
# Epoch 109/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0054 - mae: 0.0591
# Epoch 109: val_loss improved from 0.00500 to 0.00500, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0413 - val_loss: 0.0050 - val_mae: 0.0477
# Epoch 110/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0054 - mae: 0.0591
# Epoch 110: val_loss improved from 0.00500 to 0.00500, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0413 - val_loss: 0.0050 - val_mae: 0.0476
# Epoch 111/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0054 - mae: 0.0591
# Epoch 111: val_loss improved from 0.00500 to 0.00499, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0413 - val_loss: 0.0050 - val_mae: 0.0476
# Epoch 112/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0053 - mae: 0.0591
# Epoch 112: val_loss improved from 0.00499 to 0.00499, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0413 - val_loss: 0.0050 - val_mae: 0.0476
# Epoch 113/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0053 - mae: 0.0590
# Epoch 113: val_loss improved from 0.00499 to 0.00499, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0413 - val_loss: 0.0050 - val_mae: 0.0476
# Epoch 114/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0053 - mae: 0.0590
# Epoch 114: val_loss improved from 0.00499 to 0.00498, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0413 - val_loss: 0.0050 - val_mae: 0.0476
# Epoch 115/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0053 - mae: 0.0590
# Epoch 115: val_loss improved from 0.00498 to 0.00498, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0029 - mae: 0.0412 - val_loss: 0.0050 - val_mae: 0.0475
# Epoch 116/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0053 - mae: 0.0589
# Epoch 116: val_loss improved from 0.00498 to 0.00498, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0029 - mae: 0.0412 - val_loss: 0.0050 - val_mae: 0.0475
# Epoch 117/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0053 - mae: 0.0589
# Epoch 117: val_loss improved from 0.00498 to 0.00498, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0412 - val_loss: 0.0050 - val_mae: 0.0475
# Epoch 118/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0053 - mae: 0.0589
# Epoch 118: val_loss improved from 0.00498 to 0.00497, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0412 - val_loss: 0.0050 - val_mae: 0.0475
# Epoch 119/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0053 - mae: 0.0589
# Epoch 119: val_loss improved from 0.00497 to 0.00497, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0412 - val_loss: 0.0050 - val_mae: 0.0475
# Epoch 120/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0053 - mae: 0.0588
# Epoch 120: val_loss improved from 0.00497 to 0.00497, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0412 - val_loss: 0.0050 - val_mae: 0.0475
# Epoch 121/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0053 - mae: 0.0588
# Epoch 121: val_loss improved from 0.00497 to 0.00497, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0412 - val_loss: 0.0050 - val_mae: 0.0474
# Epoch 122/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0053 - mae: 0.0588
# Epoch 122: val_loss improved from 0.00497 to 0.00496, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - mae: 0.0411 - val_loss: 0.0050 - val_mae: 0.0474
# Epoch 123/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0053 - mae: 0.0588
# Epoch 123: val_loss improved from 0.00496 to 0.00496, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0411 - val_loss: 0.0050 - val_mae: 0.0474
# Epoch 124/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0053 - mae: 0.0587
# Epoch 124: val_loss improved from 0.00496 to 0.00496, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0029 - mae: 0.0411 - val_loss: 0.0050 - val_mae: 0.0474
# Epoch 125/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0053 - mae: 0.0587
# Epoch 125: val_loss improved from 0.00496 to 0.00496, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0411 - val_loss: 0.0050 - val_mae: 0.0474
# Epoch 126/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0053 - mae: 0.0587
# Epoch 126: val_loss improved from 0.00496 to 0.00496, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0029 - mae: 0.0411 - val_loss: 0.0050 - val_mae: 0.0474
# Epoch 127/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0053 - mae: 0.0587
# Epoch 127: val_loss improved from 0.00496 to 0.00495, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0029 - mae: 0.0411 - val_loss: 0.0050 - val_mae: 0.0473
# Epoch 128/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0053 - mae: 0.0586
# Epoch 128: val_loss improved from 0.00495 to 0.00495, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0411 - val_loss: 0.0050 - val_mae: 0.0473
# Epoch 129/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0053 - mae: 0.0586
# Epoch 129: val_loss improved from 0.00495 to 0.00495, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0411 - val_loss: 0.0049 - val_mae: 0.0473
# Epoch 130/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0053 - mae: 0.0586
# Epoch 130: val_loss improved from 0.00495 to 0.00495, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0410 - val_loss: 0.0049 - val_mae: 0.0473
# Epoch 131/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0053 - mae: 0.0586
# Epoch 131: val_loss improved from 0.00495 to 0.00495, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0410 - val_loss: 0.0049 - val_mae: 0.0473
# Epoch 132/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0053 - mae: 0.0586
# Epoch 132: val_loss improved from 0.00495 to 0.00494, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0029 - mae: 0.0410 - val_loss: 0.0049 - val_mae: 0.0473
# Epoch 133/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0053 - mae: 0.0585
# Epoch 133: val_loss improved from 0.00494 to 0.00494, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0029 - mae: 0.0410 - val_loss: 0.0049 - val_mae: 0.0472
# Epoch 134/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0053 - mae: 0.0585
# Epoch 134: val_loss improved from 0.00494 to 0.00494, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0029 - mae: 0.0410 - val_loss: 0.0049 - val_mae: 0.0472
# Epoch 135/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0053 - mae: 0.0585
# Epoch 135: val_loss improved from 0.00494 to 0.00494, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0029 - mae: 0.0410 - val_loss: 0.0049 - val_mae: 0.0472
# Epoch 136/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0053 - mae: 0.0585
# Epoch 136: val_loss improved from 0.00494 to 0.00494, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mae: 0.0410 - val_loss: 0.0049 - val_mae: 0.0472
# Epoch 137/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0052 - mae: 0.0584
# Epoch 137: val_loss improved from 0.00494 to 0.00493, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0028 - mae: 0.0410 - val_loss: 0.0049 - val_mae: 0.0472
# Epoch 138/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0052 - mae: 0.0584
# Epoch 138: val_loss improved from 0.00493 to 0.00493, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0028 - mae: 0.0409 - val_loss: 0.0049 - val_mae: 0.0472
# Epoch 139/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0052 - mae: 0.0584
# Epoch 139: val_loss improved from 0.00493 to 0.00493, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028 - mae: 0.0409 - val_loss: 0.0049 - val_mae: 0.0472
# Epoch 140/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0052 - mae: 0.0584
# Epoch 140: val_loss improved from 0.00493 to 0.00493, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0409 - val_loss: 0.0049 - val_mae: 0.0472
# Epoch 141/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0052 - mae: 0.0584
# Epoch 141: val_loss improved from 0.00493 to 0.00493, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0409 - val_loss: 0.0049 - val_mae: 0.0471
# Epoch 142/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0052 - mae: 0.0583
# Epoch 142: val_loss improved from 0.00493 to 0.00493, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028 - mae: 0.0409 - val_loss: 0.0049 - val_mae: 0.0471
# Epoch 143/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0052 - mae: 0.0583
# Epoch 143: val_loss improved from 0.00493 to 0.00492, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mae: 0.0409 - val_loss: 0.0049 - val_mae: 0.0471
# Epoch 144/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0052 - mae: 0.0583
# Epoch 144: val_loss improved from 0.00492 to 0.00492, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mae: 0.0409 - val_loss: 0.0049 - val_mae: 0.0471
# Epoch 145/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0052 - mae: 0.0583
# Epoch 145: val_loss improved from 0.00492 to 0.00492, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0409 - val_loss: 0.0049 - val_mae: 0.0471
# Epoch 146/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0052 - mae: 0.0583
# Epoch 146: val_loss improved from 0.00492 to 0.00492, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0409 - val_loss: 0.0049 - val_mae: 0.0471
# Epoch 147/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0052 - mae: 0.0582
# Epoch 147: val_loss improved from 0.00492 to 0.00492, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0028 - mae: 0.0408 - val_loss: 0.0049 - val_mae: 0.0471
# Epoch 148/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0052 - mae: 0.0582
# Epoch 148: val_loss improved from 0.00492 to 0.00492, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028 - mae: 0.0408 - val_loss: 0.0049 - val_mae: 0.0471
# Epoch 149/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0052 - mae: 0.0582
# Epoch 149: val_loss improved from 0.00492 to 0.00492, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0408 - val_loss: 0.0049 - val_mae: 0.0470
# Epoch 150/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0052 - mae: 0.0582
# Epoch 150: val_loss improved from 0.00492 to 0.00491, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0028 - mae: 0.0408 - val_loss: 0.0049 - val_mae: 0.0470
# Epoch 151/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0052 - mae: 0.0581
# Epoch 151: val_loss improved from 0.00491 to 0.00491, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0408 - val_loss: 0.0049 - val_mae: 0.0470
# Epoch 152/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0052 - mae: 0.0581
# Epoch 152: val_loss improved from 0.00491 to 0.00491, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0408 - val_loss: 0.0049 - val_mae: 0.0470
# Epoch 153/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0052 - mae: 0.0581
# Epoch 153: val_loss improved from 0.00491 to 0.00491, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0408 - val_loss: 0.0049 - val_mae: 0.0470
# Epoch 154/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0052 - mae: 0.0581
# Epoch 154: val_loss improved from 0.00491 to 0.00491, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0408 - val_loss: 0.0049 - val_mae: 0.0470
# Epoch 155/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0052 - mae: 0.0581
# Epoch 155: val_loss improved from 0.00491 to 0.00491, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0408 - val_loss: 0.0049 - val_mae: 0.0470
# Epoch 156/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0052 - mae: 0.0581
# Epoch 156: val_loss improved from 0.00491 to 0.00491, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0028 - mae: 0.0408 - val_loss: 0.0049 - val_mae: 0.0470
# Epoch 157/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0052 - mae: 0.0580
# Epoch 157: val_loss improved from 0.00491 to 0.00491, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0407 - val_loss: 0.0049 - val_mae: 0.0470
# Epoch 158/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0052 - mae: 0.0580
# Epoch 158: val_loss improved from 0.00491 to 0.00490, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0028 - mae: 0.0407 - val_loss: 0.0049 - val_mae: 0.0469
# Epoch 159/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0052 - mae: 0.0580
# Epoch 159: val_loss improved from 0.00490 to 0.00490, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0407 - val_loss: 0.0049 - val_mae: 0.0469
# Epoch 160/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0052 - mae: 0.0580
# Epoch 160: val_loss improved from 0.00490 to 0.00490, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0407 - val_loss: 0.0049 - val_mae: 0.0469
# Epoch 161/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0052 - mae: 0.0580
# Epoch 161: val_loss improved from 0.00490 to 0.00490, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0028 - mae: 0.0407 - val_loss: 0.0049 - val_mae: 0.0469
# Epoch 162/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0052 - mae: 0.0579
# Epoch 162: val_loss improved from 0.00490 to 0.00490, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0407 - val_loss: 0.0049 - val_mae: 0.0469
# Epoch 163/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0052 - mae: 0.0579
# Epoch 163: val_loss improved from 0.00490 to 0.00490, saving model to ../../modeling/Model/GRU_best.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0028 - mae: 0.0407 - val_loss: 0.0049 - val_mae: 0.0469
# Epoch 164/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0052 - mae: 0.0579
# Epoch 164: val_loss improved from 0.00490 to 0.00490, saving model to ../../modeling/Model/GRU_best.keras
# ...
# Epoch 433/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0049 - mae: 0.0560
# Epoch 433: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0399 - val_loss: 0.0048 - val_mae: 0.0464
# Epoch 434/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0049 - mae: 0.0560
# Epoch 434: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0027 - mae: 0.0399 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 435/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0049 - mae: 0.0560
# Epoch 435: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 436/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0049 - mae: 0.0560
# Epoch 436: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 437/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0049 - mae: 0.0560
# Epoch 437: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 438/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 438: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 439/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 439: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 440/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 440: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 441/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 441: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 442/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 442: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 443/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 443: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 444/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 444: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 445/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 445: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 446/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 446: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 447/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 447: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 448/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 448: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 449/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 449: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 450/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 450: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 451/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0049 - mae: 0.0559
# Epoch 451: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 452/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0049 - mae: 0.0558
# Epoch 452: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0465
# Epoch 453/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0049 - mae: 0.0558
# Epoch 453: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 454/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0049 - mae: 0.0558
# Epoch 454: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 455/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0049 - mae: 0.0558
# Epoch 455: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 456/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0049 - mae: 0.0558
# Epoch 456: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 457/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0049 - mae: 0.0558
# Epoch 457: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 458/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0049 - mae: 0.0558
# Epoch 458: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 459/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - mae: 0.0448
# Epoch 459: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 460/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0049 - mae: 0.0558
# Epoch 460: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 461/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0049 - mae: 0.0558
# Epoch 461: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 462/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0049 - mae: 0.0558
# Epoch 462: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 463/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0049 - mae: 0.0558
# Epoch 463: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 464/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0048 - mae: 0.0558
# Epoch 464: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 465/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0048 - mae: 0.0558
# Epoch 465: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 466/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0048 - mae: 0.0558
# Epoch 466: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 467/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 467: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 468/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - mae: 0.0448
# Epoch 468: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 469/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 469: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 470/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 470: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0466
# Epoch 471/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 471: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0467
# Epoch 472/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 472: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0467
# Epoch 473/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 473: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0467
# Epoch 474/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 474: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0467
# Epoch 475/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 475: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0467
# Epoch 476/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 476: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0467
# Epoch 477/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 477: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0467
# Epoch 478/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 478: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0467
# Epoch 479/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 479: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 480/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 480: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 481/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0048 - mae: 0.0557
# Epoch 481: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 482/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 482: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 483/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 483: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 484/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 484: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 485/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 485: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 486/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 486: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 487/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 487: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 488/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 488: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 489/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 489: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 490/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 490: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0467
# Epoch 491/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 491: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0468
# Epoch 492/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 492: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0468
# Epoch 493/500
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033 - mae: 0.0447
# Epoch 493: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0468
# Epoch 494/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 494: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0468
# Epoch 495/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 495: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0468
# Epoch 496/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 496: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0468
# Epoch 497/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 497: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0468
# Epoch 498/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0048 - mae: 0.0555
# Epoch 498: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0468
# Epoch 499/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0048 - mae: 0.0555
# Epoch 499: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0468
# Epoch 500/500
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0048 - mae: 0.0556
# Epoch 500: val_loss did not improve from 0.00465
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0027 - mae: 0.0398 - val_loss: 0.0049 - val_mae: 0.0468

# %%
from tensorflow.keras.models import load_model

# 체크포인트에서 최적 모델 불러오기
best_model = load_model(checkpoint_path)
# ===============================
# 8. 예측 + y 스케일 해제 (하루씩 예측)
# ===============================
pred_list = []

for i in range(len(X_test)):
    # i번째 테스트 구간 하나만 꺼냄: shape = (1, SEQ_LEN, num_features)
    x_input = X_test[i:i+1]

    # 하루치 예측 (출력 shape: (1, 1) 가정)
    pred_i = model.predict(x_input, verbose=0)[0, 0]
    pred_list.append(pred_i)

# 리스트 -> 배열로 변환
pred_scaled   = np.array(pred_list).reshape(-1, 1)  # (N_test, 1)
y_test_scaled = y_test                              # (N_test, 1)

# MinMax 역변환 (원래 y_target 스케일)
y_test_inv = scaler_y.inverse_transform(y_test_scaled)
pred_inv   = scaler_y.inverse_transform(pred_scaled)

# %%
# ===============================
# 9. Date도 test 구간에 맞게 자르기
# ===============================
start_idx = SEQ_LEN + train_size + val_size
end_idx   = start_idx + len(y_test_inv)

# df가 아니라 df_num에 맞춘 dates_num 사용 (인덱스 정합)
date_test = dates_num.iloc[start_idx:end_idx].reset_index(drop=True)

# ===============================
# 10. 결과 DataFrame (원래 스케일)
# ===============================
result = pd.DataFrame({
    "Date": date_test,
    "y_true": y_test_inv.flatten(),
    "y_pred": pred_inv.flatten()
})

print(result.head())
# Out:
#         Date    y_true    y_pred
# 0 2025-04-07 -0.001783  0.002074
# 1 2025-04-08 -0.015787  0.002088
# 2 2025-04-09  0.099863  0.002751
# 3 2025-04-10 -0.044808  0.001962
# 4 2025-04-11  0.017686  0.003071

# %%
# ===============================
# 10. 결과 DataFrame (원래 스케일)
# ===============================
result = pd.DataFrame({
    "Date": date_test,
    "y_true": y_test_inv.flatten(),
    "y_pred": pred_inv.flatten()
})

print(result.head())

# ===============================
# 11. 지표 (RMSE / MAE / R²) - 원래 스케일 기준
# ===============================
rmse = np.sqrt(mean_squared_error(result["y_true"], result["y_pred"]))
mae  = mean_absolute_error(result["y_true"], result["y_pred"])
r2   = r2_score(result["y_true"], result["y_pred"])

print(f"Test RMSE (original scale): {rmse:.4f}")
print(f"Test MAE  (original scale): {mae:.4f}")
print(f"Test R^2  (original scale): {r2:.4f}")

# ===============================
# 12. 그래프: True vs Pred (원래 스케일)
# ===============================
plt.figure(figsize=(12, 4))
plt.plot(result["Date"], result["y_true"], label="True", linewidth=2)
plt.plot(result["Date"], result["y_pred"], label="Predicted", alpha=0.7)
plt.title("GRU Prediction vs True (Original Scale, Test)")
plt.xlabel("Date")
plt.ylabel(target_col + " (original)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#         Date    y_true    y_pred
# 0 2025-04-07 -0.001783  0.002074
# 1 2025-04-08 -0.015787  0.002088
# 2 2025-04-09  0.099863  0.002751
# 3 2025-04-10 -0.044808  0.001962
# 4 2025-04-11  0.017686  0.003071
# Test RMSE (original scale): 0.0120
# Test MAE  (original scale): 0.0068
# Test R^2  (original scale): 0.0061

# %%
# ===============================
# 13. 잔차(residual) 분석 (원래 스케일)
# ===============================
residuals = result["y_true"] - result["y_pred"]

plt.figure(figsize=(12, 3))
plt.plot(result["Date"], residuals)
plt.title("Residuals over time (original scale)")
plt.xlabel("Date")
plt.ylabel("y_true - y_pred")
plt.tight_layout()
plt.show()

plt.figure(figsize=(5, 4))
plt.hist(residuals, bins=30)
plt.title("Residual distribution (original scale)")
plt.tight_layout()
plt.show()

# %%
print(f"\n✅ 최적 seq_len = {best_seq_len}, best val_loss = {best_val_loss:.6f}")
# Out:
# ✅ 최적 seq_len = 7, best val_loss = 0.005126

# %%
# ===============================
# 7-1. 학습 곡선 시각화 (Loss / MAE)
# ===============================
# history.history 안에 들어있는 키 확인 (디버깅용)
print(history.history.keys())

# 1) Loss (train vs val)
plt.figure(figsize=(8, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.tight_layout()
plt.show()

# 2) MAE (train vs val)
if "mae" in history.history and "val_mae" in history.history:
    plt.figure(figsize=(8, 4))
    plt.plot(history.history["mae"], label="Train MAE")
    plt.plot(history.history["val_mae"], label="Val MAE")
    plt.title("Training & Validation MAE")
    plt.xlabel("Epoch")
    plt.ylabel("MAE")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
# ===============================
# 12. 예측 수익률 → 예측 S&P500 지수로 변환
# ===============================

# 👉 실제 S&P500 지수(예: 종가)가 들어있는 컬럼명
price_col = "y_target_log"   # df에서 S&P500 지수 컬럼명으로 바꿔도 됨

# test 구간 길이
n_test = len(y_test_inv)

# y_test / pred가 대응하는 원본 인덱스 범위 (이미 위에서 쓴 start_idx 그대로 사용)
start_idx = SEQ_LEN + train_size + val_size
idx_curr_start = start_idx
idx_curr_end   = start_idx + n_test   # end는 exclusive

# 1) 실제 S&P500 지수 (오늘 기준 P_t)
price_true = df[price_col].iloc[idx_curr_start:idx_curr_end].to_numpy()

# 2) 수익률 기준이 되는 "어제 지수" P_{t-1}
price_prev = df[price_col].iloc[idx_curr_start-1:idx_curr_start-1 + n_test].to_numpy()

# 3) 예측/실제 수익률 (디스케일링된 값)
ret_true = y_test_inv.flatten()   # 실제 ret_prev
ret_pred = pred_inv.flatten()     # 예측 ret_prev

# 4) 수익률 → 지수로 복원
#    여기서 price_prev는 이미 P_{t-1}이므로 shift 쓸 필요 없음
#    P_t = P_{t-1} * (1 + ret_prev_t)
price_pred_from_ret = price_prev + ret_pred   # 예측 지수
price_true_from_ret = price_prev + ret_true # 검증용 지수 (price_true와 거의 같아야 정상)

# 5) 결과 DataFrame (날짜 + 실제 지수 + 예측 지수)
result_price = pd.DataFrame({
    "Date": date_test.reset_index(drop=True),
    "Price_true_df": price_true,              # df에서 직접 가져온 실제 지수
    "Price_true_from_ret": price_true_from_ret,  # ret_prev로 다시 계산한 실제 지수
    "Price_pred": price_pred_from_ret         # 예측 수익률로부터 복원한 지수
})

print(result_price.head())

# 6) 지수 기준 RMSE / MAE / R^2
rmse_price = np.sqrt(mean_squared_error(result_price["Price_true_df"], result_price["Price_pred"]))
mae_price  = mean_absolute_error(result_price["Price_true_df"], result_price["Price_pred"])
r2_price   = r2_score(result_price["Price_true_df"], result_price["Price_pred"])

print(f"Price RMSE : {rmse_price:.4f}")
print(f"Price MAE  : {mae_price:.4f}")
print(f"Price R^2  : {r2_price:.4f}")

# 7) 그래프: 실제 S&P500 지수 vs 예측 S&P500 지수
plt.figure(figsize=(12, 4))
plt.plot(result_price["Date"], result_price["Price_true_df"], label="True Index", linewidth=2)
plt.plot(result_price["Date"], result_price["Price_pred"], label="Predicted Index", alpha=0.7)
plt.title("S&P500 Index Level: True vs Predicted (from ret_prev)")
plt.xlabel("Date")
plt.ylabel("Index Level (e.g., S&P500)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#         Date  Price_true_df  Price_true_from_ret  Price_pred
# 0 2025-04-07       6.225113             6.283657    6.287514
# 1 2025-04-08       6.223330             6.209326    6.227201
# 2 2025-04-09       6.207543             6.323193    6.226081
# 3 2025-04-10       6.307406             6.162735    6.209505
# 4 2025-04-11       6.262598             6.325092    6.310477
# Price RMSE : 0.0132
# Price MAE  : 0.0073
# Price R^2  : 0.9694

# %%
# ===============================
# 8. 지표(RMSE, MAE, R^2) CSV로 저장 (행/열 반전 버전)
# ===============================
metrics_df = pd.DataFrame({
    "Top60_GRU_RMSE": [rmse_price],
    "Top60_GRU_R2":   [r2_price]
})

output_path = "../../modeling/성능지표/SPY_GRU_지표.CSV"

metrics_df.to_csv(output_path, index=False, encoding="utf-8-sig")
print(f"지표 저장 완료: {output_path}")
# Out:
# 지표 저장 완료: ../../modeling/성능지표/SPY_GRU_지표.CSV

# %%
# # ===============================
# # 9. 최종 GRU 모델 저장
# # ===============================
# import os

# save_dir = "C:\Users\samsung\OneDrive\Desktop\본프\찐"   # 원하는 폴더 경로로 수정하세요
# os.makedirs(save_dir, exist_ok=True)

# model_path = os.path.join(save_dir, f"gru_seq{SEQ_LEN}_best.keras")  # 또는 .h5
# model.save(model_path)   # 모델 구조 + 가중치 같이 저장

# print(f"✅ 최종 모델 저장 완료: {model_path}")
