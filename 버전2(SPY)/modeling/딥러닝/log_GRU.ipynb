# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


# 0. 시드 고정 (재현성)
SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# 1. 데이터 로드

df = pd.read_csv('../../preprocessing/log공선성제거_Final_data.csv')
df["ret_prev"] = (df["y_target_log"] - df["y_target_log"].shift(1))

# Date 컬럼
date_col = "Date"

# y_target 컬럼 (타깃)
target_col = "ret_prev"

df[date_col] = pd.to_datetime(df[date_col])

# 숫자형만 사용 + 결측 제거
df_num = df.select_dtypes(include=[np.number]).dropna()

# 숫자행에 맞는 날짜만 따로 정렬 (인덱스 맞추기용)
dates_num = df.loc[df_num.index, date_col].reset_index(drop=True)

# X: y_target 제외
feature_cols = [c for c in df_num.columns if c != target_col or 'y_target_log']
X_raw = df_num[feature_cols].values        # (N, num_features)
y_raw = df_num[[target_col]].values       # (N, 1)

print("X_raw shape:", X_raw.shape)
print("y_raw shape:", y_raw.shape)
# Out:
# X_raw shape: (753, 7)
# y_raw shape: (753, 1)

# %%
# 2. 스케일링 (X / y 따로)

scaler_X = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X_raw)

scaler_y = MinMaxScaler()
y_scaled = scaler_y.fit_transform(y_raw)


# 3. 시계열 데이터셋 생성 함수

def make_dataset(X_arr, y_arr, seq_len):
    Xs, ys = [], []
    for i in range(len(X_arr) - seq_len):
        Xs.append(X_arr[i:i+seq_len])      # (seq_len, num_features)
        ys.append(y_arr[i+seq_len])        # (1,)
    return np.array(Xs), np.array(ys)

# 4. 모델 정의 (GRU only)

def build_model(seq_len, num_features):
    inputs = Input(shape=(seq_len, num_features))

    # GRU 스택
    x = GRU(64, return_sequences=True)(inputs)

    outputs = Dense(1)(x)

    model = Model(inputs, outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(0.001),
        loss='mse',
        metrics=['mae']
    )
    return model

# %%
# 5. seq_len 후보 [5,15,30,60,90] 중 최적 선택 (val_loss 기준)

candidate_seq_lens = list(range(1, 51))


best_seq_len  = None
best_val_loss = np.inf

for seq_len in candidate_seq_lens:
    # 1) 시퀀스 데이터 생성
    X_tmp, y_tmp = make_dataset(X_scaled, y_scaled, seq_len)
    n_samples = len(X_tmp)

    if n_samples < 10:
        print(f"seq_len={seq_len} → 샘플 수 부족 (n={n_samples}), 스킵")
        continue

    # 2) Train / Val / Test 분할 
    test_size = int(n_samples * 0.20)
    remaining = n_samples - test_size
    val_size = int(remaining * 0.20)
    train_size = remaining - val_size
    val_end    = train_size + val_size
    train_end  = train_size

    X_train_tmp = X_tmp[:train_end]
    y_train_tmp = y_tmp[:train_end]

    X_val_tmp   = X_tmp[train_end:val_end]
    y_val_tmp   = y_tmp[train_end:val_end]

    # 3) 임시 모델 생성
    model_tmp = build_model(seq_len, X_tmp.shape[2])

    early_tmp = tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )

    # 4) 학습
    history_tmp = model_tmp.fit(
        X_train_tmp, y_train_tmp,
        validation_data=(X_val_tmp, y_val_tmp),
        epochs=200,
        batch_size=64,
        callbacks=[early_tmp],
        verbose=0,
        shuffle=False)

    # 5) 최소 val_loss
    val_loss = min(history_tmp.history["val_loss"])
    print(f"seq_len={seq_len} → best val_loss={val_loss:.6f}")

    # 6) 최적 seq_len 갱신
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_seq_len  = seq_len

print(f"\n최적 seq_len = {best_seq_len}, best val_loss = {best_val_loss:.6f}")
# Out:
# seq_len=1 → best val_loss=0.005063
# seq_len=2 → best val_loss=0.005187
# seq_len=3 → best val_loss=0.005305
# seq_len=4 → best val_loss=0.005312
# seq_len=5 → best val_loss=0.005366
# seq_len=6 → best val_loss=0.005537
# seq_len=7 → best val_loss=0.005597
# seq_len=8 → best val_loss=0.006537
# seq_len=9 → best val_loss=0.005604
# seq_len=10 → best val_loss=0.005182
# seq_len=11 → best val_loss=0.005855
# seq_len=12 → best val_loss=0.005797
# seq_len=13 → best val_loss=0.005693
# seq_len=14 → best val_loss=0.008649
# seq_len=15 → best val_loss=0.008629
# seq_len=16 → best val_loss=0.008927
# seq_len=17 → best val_loss=0.008763
# seq_len=18 → best val_loss=0.008745
# seq_len=19 → best val_loss=0.009423
# seq_len=20 → best val_loss=0.009462
# seq_len=21 → best val_loss=0.009387
# seq_len=22 → best val_loss=0.009395
# seq_len=23 → best val_loss=0.009439
# seq_len=24 → best val_loss=0.009601
# seq_len=25 → best val_loss=0.009661
# seq_len=26 → best val_loss=0.009645
# seq_len=27 → best val_loss=0.009640
# seq_len=28 → best val_loss=0.009548
# seq_len=29 → best val_loss=0.009608
# seq_len=30 → best val_loss=0.009683
# seq_len=31 → best val_loss=0.009729
# seq_len=32 → best val_loss=0.009697
# seq_len=33 → best val_loss=0.009793
# seq_len=34 → best val_loss=0.009798
# seq_len=35 → best val_loss=0.009704
# seq_len=36 → best val_loss=0.009762
# seq_len=37 → best val_loss=0.009867
# seq_len=38 → best val_loss=0.009866
# seq_len=39 → best val_loss=0.009913
# seq_len=40 → best val_loss=0.010005
# seq_len=41 → best val_loss=0.009960
# seq_len=42 → best val_loss=0.009932
# seq_len=43 → best val_loss=0.009906
# seq_len=44 → best val_loss=0.009900
# seq_len=45 → best val_loss=0.009778
# seq_len=46 → best val_loss=0.009886
# seq_len=47 → best val_loss=0.009902
# seq_len=48 → best val_loss=0.009913
# seq_len=49 → best val_loss=0.013620
# seq_len=50 → best val_loss=0.010141
#
# 최적 seq_len = 1, best val_loss = 0.005063

# %%
# 최적 seq_len으로 다시 시퀀스 생성
X_best, y_best = make_dataset(X_scaled, y_scaled, best_seq_len)
n_samples = len(X_best)

train_size = int(n_samples * 0.6)
val_size   = int(n_samples * 0.2)
test_size  = n_samples - train_size - val_size

print(f"전체 샘플 수 (n_samples): {n_samples}")
print(f"train 샘플 수          : {train_size}")
print(f"val 샘플 수            : {val_size}")
print(f"test(남는 구간) 샘플 수 : {test_size}")

print("X_best shape:", X_best.shape)
print("y_best shape:", y_best.shape)
# Out:
# 전체 샘플 수 (n_samples): 752
# train 샘플 수          : 451
# val 샘플 수            : 150
# test(남는 구간) 샘플 수 : 151
# X_best shape: (752, 1, 7)
# y_best shape: (752, 1)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 7. 최종 모델 정의 및 학습 + 최적 모델 저장


SEQ_LEN = best_seq_len  


X_train = X_best[:train_size]
y_train = y_best[:train_size]

X_val   = X_best[train_size:train_size+val_size]
y_val   = y_best[train_size:train_size+val_size]

X_test  = X_best[train_size+val_size:]
y_test  = y_best[train_size+val_size:]

# 최종 모델 생성
model = build_model(SEQ_LEN, X_train.shape[2])
model.summary()

# EarlyStopping (가장 좋은 weight로 복원)
early = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

# ModelCheckpoint: val_loss가 갱신될 때만 모델 저장
checkpoint_path = "../../modeling/Model/GRU_best.keras"  # 저장 경로 원하는 대로 수정
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path,
    monitor='val_loss',
    save_best_only=True,   # 가장 좋은 모델만 저장
    save_weights_only=False,  # 전체 모델(구조+가중치) 저장
    mode='min',
    verbose=1
)

# 학습: 콜백에 EarlyStopping + Checkpoint 둘 다 넣기
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=500,
    batch_size=64,
    # callbacks=[early, checkpoint],
    callbacks=[checkpoint], 
    verbose=1,
    shuffle=False
)
# Out:
# Model: "functional_50"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_50 (InputLayer)     │ (None, 1, 7)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_50 (GRU)                    │ (None, 1, 64)          │        14,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_50 (Dense)                │ (None, 1, 1)           │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,081 (55.00 KB)
#  Trainable params: 14,081 (55.00 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - loss: 0.1940 - mae: 0.4326
# Epoch 1: val_loss improved from None to 0.04812, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.1344 - mae: 0.3581 - val_loss: 0.0481 - val_mae: 0.2115
# Epoch 2/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0852 - mae: 0.2795
# Epoch 2: val_loss improved from 0.04812 to 0.00635, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0473 - mae: 0.2022 - val_loss: 0.0063 - val_mae: 0.0647
# Epoch 3/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0273 - mae: 0.1417
# Epoch 3: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0114 - mae: 0.0850 - val_loss: 0.0127 - val_mae: 0.0931
# Epoch 4/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0097 - mae: 0.0744
# Epoch 4: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069 - mae: 0.0639 - val_loss: 0.0250 - val_mae: 0.1411
# Epoch 5/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0089 - mae: 0.0745
# Epoch 5: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0074 - mae: 0.0685 - val_loss: 0.0209 - val_mae: 0.1268
# Epoch 6/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0087 - mae: 0.0725
# Epoch 6: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0053 - mae: 0.0558 - val_loss: 0.0125 - val_mae: 0.0920
# Epoch 7/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0092 - mae: 0.0728
# Epoch 7: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0047 - mae: 0.0517 - val_loss: 0.0084 - val_mae: 0.0699
# Epoch 8/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0104 - mae: 0.0768
# Epoch 8: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0052 - mae: 0.0546 - val_loss: 0.0078 - val_mae: 0.0658
# Epoch 9/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0105 - mae: 0.0772
# Epoch 9: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0052 - mae: 0.0543 - val_loss: 0.0086 - val_mae: 0.0708
# Epoch 10/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0098 - mae: 0.0746
# Epoch 10: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0049 - mae: 0.0526 - val_loss: 0.0095 - val_mae: 0.0761
# Epoch 11/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0092 - mae: 0.0727
# Epoch 11: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0047 - mae: 0.0515 - val_loss: 0.0095 - val_mae: 0.0764
# Epoch 12/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0090 - mae: 0.0720
# Epoch 12: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0046 - mae: 0.0508 - val_loss: 0.0089 - val_mae: 0.0728
# Epoch 13/500
# 4/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0065 - mae: 0.0611
# Epoch 13: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0045 - mae: 0.0505 - val_loss: 0.0083 - val_mae: 0.0692
# Epoch 14/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0089 - mae: 0.0719
# Epoch 14: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0045 - mae: 0.0504 - val_loss: 0.0080 - val_mae: 0.0674
# Epoch 15/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0089 - mae: 0.0715
# Epoch 15: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0044 - mae: 0.0500 - val_loss: 0.0079 - val_mae: 0.0666
# Epoch 16/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0087 - mae: 0.0709
# Epoch 16: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - mae: 0.0496 - val_loss: 0.0077 - val_mae: 0.0658
# Epoch 17/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0086 - mae: 0.0704
# Epoch 17: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - mae: 0.0492 - val_loss: 0.0075 - val_mae: 0.0645
# Epoch 18/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0085 - mae: 0.0700
# Epoch 18: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042 - mae: 0.0488 - val_loss: 0.0073 - val_mae: 0.0630
# Epoch 19/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0084 - mae: 0.0696
# Epoch 19: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0041 - mae: 0.0485 - val_loss: 0.0071 - val_mae: 0.0618
# Epoch 20/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0083 - mae: 0.0692
# Epoch 20: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0041 - mae: 0.0482 - val_loss: 0.0069 - val_mae: 0.0607
# Epoch 21/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0082 - mae: 0.0688
# Epoch 21: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - mae: 0.0479 - val_loss: 0.0067 - val_mae: 0.0597
# Epoch 22/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0081 - mae: 0.0684
# Epoch 22: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0040 - mae: 0.0476 - val_loss: 0.0065 - val_mae: 0.0586
# Epoch 23/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0080 - mae: 0.0680
# Epoch 23: val_loss did not improve from 0.00635
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0039 - mae: 0.0473 - val_loss: 0.0064 - val_mae: 0.0576
# Epoch 24/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0080 - mae: 0.0677
# Epoch 24: val_loss improved from 0.00635 to 0.00622, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0039 - mae: 0.0470 - val_loss: 0.0062 - val_mae: 0.0566
# Epoch 25/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0079 - mae: 0.0674
# Epoch 25: val_loss improved from 0.00622 to 0.00608, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038 - mae: 0.0467 - val_loss: 0.0061 - val_mae: 0.0557
# Epoch 26/500
# 3/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0061 - mae: 0.0588
# Epoch 26: val_loss improved from 0.00608 to 0.00595, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0038 - mae: 0.0465 - val_loss: 0.0059 - val_mae: 0.0548
# Epoch 27/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0078 - mae: 0.0669
# Epoch 27: val_loss improved from 0.00595 to 0.00582, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0037 - mae: 0.0462 - val_loss: 0.0058 - val_mae: 0.0539
# Epoch 28/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0077 - mae: 0.0666
# Epoch 28: val_loss improved from 0.00582 to 0.00570, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0037 - mae: 0.0460 - val_loss: 0.0057 - val_mae: 0.0531
# Epoch 29/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0077 - mae: 0.0663
# Epoch 29: val_loss improved from 0.00570 to 0.00558, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0037 - mae: 0.0458 - val_loss: 0.0056 - val_mae: 0.0524
# Epoch 30/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0076 - mae: 0.0661
# Epoch 30: val_loss improved from 0.00558 to 0.00548, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0036 - mae: 0.0455 - val_loss: 0.0055 - val_mae: 0.0517
# Epoch 31/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0076 - mae: 0.0659
# Epoch 31: val_loss improved from 0.00548 to 0.00538, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0036 - mae: 0.0453 - val_loss: 0.0054 - val_mae: 0.0510
# Epoch 32/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0075 - mae: 0.0656
# Epoch 32: val_loss improved from 0.00538 to 0.00529, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0036 - mae: 0.0451 - val_loss: 0.0053 - val_mae: 0.0505
# Epoch 33/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0075 - mae: 0.0654
# Epoch 33: val_loss improved from 0.00529 to 0.00520, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - mae: 0.0449 - val_loss: 0.0052 - val_mae: 0.0499
# Epoch 34/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0075 - mae: 0.0652
# Epoch 34: val_loss improved from 0.00520 to 0.00512, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - mae: 0.0447 - val_loss: 0.0051 - val_mae: 0.0494
# Epoch 35/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0074 - mae: 0.0651
# Epoch 35: val_loss improved from 0.00512 to 0.00504, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0035 - mae: 0.0446 - val_loss: 0.0050 - val_mae: 0.0489
# Epoch 36/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0074 - mae: 0.0650
# Epoch 36: val_loss improved from 0.00504 to 0.00497, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034 - mae: 0.0444 - val_loss: 0.0050 - val_mae: 0.0485
# Epoch 37/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0074 - mae: 0.0649
# Epoch 37: val_loss improved from 0.00497 to 0.00490, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0034 - mae: 0.0443 - val_loss: 0.0049 - val_mae: 0.0482
# Epoch 38/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0073 - mae: 0.0648
# Epoch 38: val_loss improved from 0.00490 to 0.00484, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034 - mae: 0.0441 - val_loss: 0.0048 - val_mae: 0.0478
# Epoch 39/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0073 - mae: 0.0648
# Epoch 39: val_loss improved from 0.00484 to 0.00478, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0048 - val_mae: 0.0476
# Epoch 40/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0073 - mae: 0.0647
# Epoch 40: val_loss improved from 0.00478 to 0.00472, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0034 - mae: 0.0439 - val_loss: 0.0047 - val_mae: 0.0473
# Epoch 41/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0073 - mae: 0.0647
# Epoch 41: val_loss improved from 0.00472 to 0.00467, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033 - mae: 0.0437 - val_loss: 0.0047 - val_mae: 0.0471
# Epoch 42/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0073 - mae: 0.0646
# Epoch 42: val_loss improved from 0.00467 to 0.00463, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033 - mae: 0.0436 - val_loss: 0.0046 - val_mae: 0.0469
# Epoch 43/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0072 - mae: 0.0646
# Epoch 43: val_loss improved from 0.00463 to 0.00458, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033 - mae: 0.0435 - val_loss: 0.0046 - val_mae: 0.0466
# Epoch 44/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0072 - mae: 0.0645
# Epoch 44: val_loss improved from 0.00458 to 0.00454, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0033 - mae: 0.0434 - val_loss: 0.0045 - val_mae: 0.0465
# Epoch 45/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0072 - mae: 0.0645
# Epoch 45: val_loss improved from 0.00454 to 0.00450, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0045 - val_mae: 0.0463
# Epoch 46/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0072 - mae: 0.0644
# Epoch 46: val_loss improved from 0.00450 to 0.00446, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0033 - mae: 0.0433 - val_loss: 0.0045 - val_mae: 0.0461
# Epoch 47/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0072 - mae: 0.0644
# Epoch 47: val_loss improved from 0.00446 to 0.00443, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0033 - mae: 0.0432 - val_loss: 0.0044 - val_mae: 0.0460
# Epoch 48/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0072 - mae: 0.0644
# Epoch 48: val_loss improved from 0.00443 to 0.00440, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - mae: 0.0431 - val_loss: 0.0044 - val_mae: 0.0458
# Epoch 49/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0072 - mae: 0.0643
# Epoch 49: val_loss improved from 0.00440 to 0.00437, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0032 - mae: 0.0430 - val_loss: 0.0044 - val_mae: 0.0457
# Epoch 50/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0071 - mae: 0.0643
# Epoch 50: val_loss improved from 0.00437 to 0.00434, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0032 - mae: 0.0430 - val_loss: 0.0043 - val_mae: 0.0456
# Epoch 51/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0071 - mae: 0.0643
# Epoch 51: val_loss improved from 0.00434 to 0.00432, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - mae: 0.0429 - val_loss: 0.0043 - val_mae: 0.0455
# Epoch 52/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0071 - mae: 0.0642
# Epoch 52: val_loss improved from 0.00432 to 0.00429, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - mae: 0.0428 - val_loss: 0.0043 - val_mae: 0.0455
# Epoch 53/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0071 - mae: 0.0642
# Epoch 53: val_loss improved from 0.00429 to 0.00427, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032 - mae: 0.0428 - val_loss: 0.0043 - val_mae: 0.0454
# Epoch 54/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0071 - mae: 0.0642
# Epoch 54: val_loss improved from 0.00427 to 0.00425, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0032 - mae: 0.0427 - val_loss: 0.0042 - val_mae: 0.0453
# Epoch 55/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - loss: 0.0071 - mae: 0.0642
# Epoch 55: val_loss improved from 0.00425 to 0.00423, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0032 - mae: 0.0427 - val_loss: 0.0042 - val_mae: 0.0452
# Epoch 56/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0071 - mae: 0.0641
# Epoch 56: val_loss improved from 0.00423 to 0.00421, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0032 - mae: 0.0426 - val_loss: 0.0042 - val_mae: 0.0451
# Epoch 57/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0071 - mae: 0.0641
# Epoch 57: val_loss improved from 0.00421 to 0.00419, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - mae: 0.0426 - val_loss: 0.0042 - val_mae: 0.0451
# Epoch 58/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0071 - mae: 0.0641
# Epoch 58: val_loss improved from 0.00419 to 0.00418, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - mae: 0.0425 - val_loss: 0.0042 - val_mae: 0.0450
# Epoch 59/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0071 - mae: 0.0641
# Epoch 59: val_loss improved from 0.00418 to 0.00416, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - mae: 0.0425 - val_loss: 0.0042 - val_mae: 0.0449
# Epoch 60/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0071 - mae: 0.0640
# Epoch 60: val_loss improved from 0.00416 to 0.00415, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - mae: 0.0425 - val_loss: 0.0041 - val_mae: 0.0449
# Epoch 61/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0071 - mae: 0.0640
# Epoch 61: val_loss improved from 0.00415 to 0.00414, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0032 - mae: 0.0424 - val_loss: 0.0041 - val_mae: 0.0448
# Epoch 62/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0071 - mae: 0.0640
# Epoch 62: val_loss improved from 0.00414 to 0.00412, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - mae: 0.0424 - val_loss: 0.0041 - val_mae: 0.0448
# Epoch 63/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0071 - mae: 0.0640
# Epoch 63: val_loss improved from 0.00412 to 0.00411, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0032 - mae: 0.0424 - val_loss: 0.0041 - val_mae: 0.0447
# Epoch 64/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0071 - mae: 0.0640
# Epoch 64: val_loss improved from 0.00411 to 0.00410, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - mae: 0.0423 - val_loss: 0.0041 - val_mae: 0.0447
# Epoch 65/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0071 - mae: 0.0639
# Epoch 65: val_loss improved from 0.00410 to 0.00409, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - mae: 0.0423 - val_loss: 0.0041 - val_mae: 0.0446
# Epoch 66/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0071 - mae: 0.0639
# Epoch 66: val_loss improved from 0.00409 to 0.00408, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - mae: 0.0423 - val_loss: 0.0041 - val_mae: 0.0446
# Epoch 67/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0071 - mae: 0.0639
# Epoch 67: val_loss improved from 0.00408 to 0.00407, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032 - mae: 0.0422 - val_loss: 0.0041 - val_mae: 0.0446
# Epoch 68/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0071 - mae: 0.0639
# Epoch 68: val_loss improved from 0.00407 to 0.00407, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0032 - mae: 0.0422 - val_loss: 0.0041 - val_mae: 0.0445
# Epoch 69/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0070 - mae: 0.0639
# Epoch 69: val_loss improved from 0.00407 to 0.00406, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0032 - mae: 0.0422 - val_loss: 0.0041 - val_mae: 0.0445
# Epoch 70/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0070 - mae: 0.0639
# Epoch 70: val_loss improved from 0.00406 to 0.00405, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0422 - val_loss: 0.0041 - val_mae: 0.0445
# Epoch 71/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0070 - mae: 0.0639
# Epoch 71: val_loss improved from 0.00405 to 0.00405, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031 - mae: 0.0421 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 72/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 72: val_loss improved from 0.00405 to 0.00404, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0421 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 73/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 73: val_loss improved from 0.00404 to 0.00403, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0421 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 74/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 74: val_loss improved from 0.00403 to 0.00403, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0421 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 75/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 75: val_loss improved from 0.00403 to 0.00402, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031 - mae: 0.0421 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 76/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 76: val_loss improved from 0.00402 to 0.00402, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0420 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 77/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 77: val_loss improved from 0.00402 to 0.00401, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0420 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 78/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 78: val_loss improved from 0.00401 to 0.00401, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - mae: 0.0420 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 79/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 79: val_loss improved from 0.00401 to 0.00400, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - mae: 0.0420 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 80/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 80: val_loss improved from 0.00400 to 0.00400, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0420 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 81/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 81: val_loss improved from 0.00400 to 0.00400, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0419 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 82/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 82: val_loss improved from 0.00400 to 0.00399, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0419 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 83/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 83: val_loss improved from 0.00399 to 0.00399, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0419 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 84/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 84: val_loss improved from 0.00399 to 0.00399, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0419 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 85/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0070 - mae: 0.0638
# Epoch 85: val_loss improved from 0.00399 to 0.00398, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0419 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 86/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 86: val_loss improved from 0.00398 to 0.00398, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - mae: 0.0419 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 87/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 87: val_loss improved from 0.00398 to 0.00398, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0419 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 88/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 88: val_loss improved from 0.00398 to 0.00397, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0419 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 89/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 89: val_loss improved from 0.00397 to 0.00397, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 90/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 90: val_loss improved from 0.00397 to 0.00397, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0040 - val_mae: 0.0443
# Epoch 91/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 91: val_loss improved from 0.00397 to 0.00397, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0040 - val_mae: 0.0442
# Epoch 92/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 92: val_loss improved from 0.00397 to 0.00396, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0040 - val_mae: 0.0442
# Epoch 93/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 93: val_loss improved from 0.00396 to 0.00396, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0040 - val_mae: 0.0442
# Epoch 94/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 94: val_loss improved from 0.00396 to 0.00396, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0040 - val_mae: 0.0442
# Epoch 95/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 95: val_loss improved from 0.00396 to 0.00396, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0040 - val_mae: 0.0442
# Epoch 96/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 96: val_loss improved from 0.00396 to 0.00395, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0040 - val_mae: 0.0442
# Epoch 97/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 97: val_loss improved from 0.00395 to 0.00395, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0040 - val_mae: 0.0442
# Epoch 98/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 98: val_loss improved from 0.00395 to 0.00395, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 99/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 99: val_loss improved from 0.00395 to 0.00395, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0031 - mae: 0.0418 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 100/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 100: val_loss improved from 0.00395 to 0.00395, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 101/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 101: val_loss improved from 0.00395 to 0.00394, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 102/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 102: val_loss improved from 0.00394 to 0.00394, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 103/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 103: val_loss improved from 0.00394 to 0.00394, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 104/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 104: val_loss improved from 0.00394 to 0.00394, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 105/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 105: val_loss improved from 0.00394 to 0.00394, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 106/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 106: val_loss improved from 0.00394 to 0.00394, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 107/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 107: val_loss improved from 0.00394 to 0.00393, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 108/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0070 - mae: 0.0637
# Epoch 108: val_loss improved from 0.00393 to 0.00393, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 109/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 109: val_loss improved from 0.00393 to 0.00393, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 110/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 110: val_loss improved from 0.00393 to 0.00393, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 111/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 111: val_loss improved from 0.00393 to 0.00393, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 112/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 112: val_loss improved from 0.00393 to 0.00393, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 113/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 113: val_loss improved from 0.00393 to 0.00393, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 114/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 114: val_loss improved from 0.00393 to 0.00392, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 115/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 115: val_loss improved from 0.00392 to 0.00392, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 116/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 116: val_loss improved from 0.00392 to 0.00392, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 117/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 117: val_loss improved from 0.00392 to 0.00392, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 118/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 118: val_loss improved from 0.00392 to 0.00392, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 119/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 119: val_loss improved from 0.00392 to 0.00392, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0417 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 120/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 120: val_loss improved from 0.00392 to 0.00392, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 121/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 121: val_loss improved from 0.00392 to 0.00391, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 122/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 122: val_loss improved from 0.00391 to 0.00391, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 123/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 123: val_loss improved from 0.00391 to 0.00391, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 124/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 124: val_loss improved from 0.00391 to 0.00391, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 125/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 2s 363ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 125: val_loss improved from 0.00391 to 0.00391, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 126/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 126: val_loss improved from 0.00391 to 0.00391, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 127/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 127: val_loss improved from 0.00391 to 0.00391, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 128/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 128: val_loss improved from 0.00391 to 0.00391, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 129/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 129: val_loss improved from 0.00391 to 0.00391, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 130/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 130: val_loss improved from 0.00391 to 0.00390, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 131/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 131: val_loss improved from 0.00390 to 0.00390, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 132/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 132: val_loss improved from 0.00390 to 0.00390, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 133/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 133: val_loss improved from 0.00390 to 0.00390, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 134/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 134: val_loss improved from 0.00390 to 0.00390, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 135/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 135: val_loss improved from 0.00390 to 0.00390, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0441
# Epoch 136/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 169ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 136: val_loss improved from 0.00390 to 0.00390, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 137/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0069 - mae: 0.0637
# Epoch 137: val_loss improved from 0.00390 to 0.00390, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 138/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 138: val_loss improved from 0.00390 to 0.00390, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 139/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 139: val_loss improved from 0.00390 to 0.00390, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 140/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 140: val_loss improved from 0.00390 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 141/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 141: val_loss improved from 0.00389 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 142/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 142: val_loss improved from 0.00389 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 143/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 143: val_loss improved from 0.00389 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 144/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 144: val_loss improved from 0.00389 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 145/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 145: val_loss improved from 0.00389 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 146/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 146: val_loss improved from 0.00389 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 147/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 147: val_loss improved from 0.00389 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 148/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 148: val_loss improved from 0.00389 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 149/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 149: val_loss improved from 0.00389 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 150/500
# 5/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0046 - mae: 0.0512
# Epoch 150: val_loss improved from 0.00389 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 151/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 151: val_loss improved from 0.00389 to 0.00389, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 152/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 152: val_loss improved from 0.00389 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 153/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 153: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 154/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 154: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 155/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 155: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 156/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 156: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 157/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 157: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 158/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 158: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 159/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 159: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 160/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 160: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 161/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 161: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 162/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 162: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 163/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 163: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 164/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 164: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 165/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 165: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 166/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 166: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# Epoch 167/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0069 - mae: 0.0636
# Epoch 167: val_loss improved from 0.00388 to 0.00388, saving model to ../../modeling/Model/GRU_best.keras
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0416 - val_loss: 0.0039 - val_mae: 0.0440
# ...
# Epoch 433/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0067 - mae: 0.0634
# Epoch 433: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0415 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 434/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0067 - mae: 0.0634
# Epoch 434: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0415 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 435/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 435: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0415 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 436/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 194ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 436: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0415 - val_loss: 0.0039 - val_mae: 0.0442
# Epoch 437/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 437: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - mae: 0.0415 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 438/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 438: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 439/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 439: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 440/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 206ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 440: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 441/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 441: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 442/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 442: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 443/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 443: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 444/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 444: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 445/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 445: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 446/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 446: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 447/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 447: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 448/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 448: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 449/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 449: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 450/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 450: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 451/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 451: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 452/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 452: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 453/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 453: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 454/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 454: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 455/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 455: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 456/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 456: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 457/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 457: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 458/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 458: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 459/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 459: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 460/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 460: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 461/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 461: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0443
# Epoch 462/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 462: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0444
# Epoch 463/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 463: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0039 - val_mae: 0.0444
# Epoch 464/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 464: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 465/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 465: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 466/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 466: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 467/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 467: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 468/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 468: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 469/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 469: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 470/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 470: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 471/500
# 7/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0041 - mae: 0.0483
# Epoch 471: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 472/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 472: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 473/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 473: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 474/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 474: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 475/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 475: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 476/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 223ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 476: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 477/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 477: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 478/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 478: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 479/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 479: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 480/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 480: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 481/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 481: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 482/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 482: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 483/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 483: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 484/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 484: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0444
# Epoch 485/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 485: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 486/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 486: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 487/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 487: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 488/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 488: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 489/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 489: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 490/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 490: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 491/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 491: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 492/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 492: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 493/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 493: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 494/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 494: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 495/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 495: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 496/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 496: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 497/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 497: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 498/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 498: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 499/500
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0067 - mae: 0.0633
# Epoch 499: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445
# Epoch 500/500
# 6/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0043 - mae: 0.0494
# Epoch 500: val_loss did not improve from 0.00386
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0031 - mae: 0.0414 - val_loss: 0.0040 - val_mae: 0.0445

# %%
from tensorflow.keras.models import load_model

# 체크포인트에서 최적 모델 불러오기
best_model = load_model(checkpoint_path)

# 8. 예측 + y 스케일 해제 (하루씩 예측)

pred_list = []

for i in range(len(X_test)):
    # i번째 테스트 구간 하나만 꺼냄: shape = (1, SEQ_LEN, num_features)
    x_input = X_test[i:i+1]

    # 하루치 예측 (출력 shape: (1, 1) 가정)
    pred_i = model.predict(x_input, verbose=0)[0, 0]
    pred_list.append(pred_i)

# 리스트 -> 배열로 변환
pred_scaled   = np.array(pred_list).reshape(-1, 1)  # (N_test, 1)
y_test_scaled = y_test                              # (N_test, 1)

# MinMax 역변환 (원래 y_target 스케일)
y_test_inv = scaler_y.inverse_transform(y_test_scaled)
pred_inv   = scaler_y.inverse_transform(pred_scaled)

# %%
# 9. Date도 test 구간에 맞게 자르기

start_idx = SEQ_LEN + train_size + val_size
end_idx   = start_idx + len(y_test_inv)

# df가 아니라 df_num에 맞춘 dates_num 사용 (인덱스 정합)
date_test = dates_num.iloc[start_idx:end_idx].reset_index(drop=True)

# %%
# 10. 결과 DataFrame (원래 스케일)

result = pd.DataFrame({
    "Date": date_test,
    "y_true": y_test_inv.flatten(),
    "y_pred": pred_inv.flatten()
})

print(result.head())

# 11. 지표 (RMSE / MAE / R²) - 원래 스케일 기준

rmse = np.sqrt(mean_squared_error(result["y_true"], result["y_pred"]))
mae  = mean_absolute_error(result["y_true"], result["y_pred"])
r2   = r2_score(result["y_true"], result["y_pred"])

print(f"Test RMSE (original scale): {rmse:.4f}")
print(f"Test MAE  (original scale): {mae:.4f}")
print(f"Test R^2  (original scale): {r2:.4f}")

# 12. 그래프: True vs Pred (원래 스케일)

plt.figure(figsize=(12, 4))
plt.plot(result["Date"], result["y_true"], label="True", linewidth=2)
plt.plot(result["Date"], result["y_pred"], label="Predicted", alpha=0.7)
plt.title("GRU Prediction vs True (Original Scale, Test)")
plt.xlabel("Date")
plt.ylabel(target_col + " (original)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#         Date    y_true    y_pred
# 0 2025-04-04 -0.060327 -0.000217
# 1 2025-04-07 -0.001783  0.000303
# 2 2025-04-08 -0.015787 -0.000034
# 3 2025-04-09  0.099863  0.001863
# 4 2025-04-10 -0.044808  0.023820
# Test RMSE (original scale): 0.0139
# Test MAE  (original scale): 0.0076
# Test R^2  (original scale): -0.1372

# %%
# 13. 잔차(residual) 분석 (원래 스케일)

residuals = result["y_true"] - result["y_pred"]

plt.figure(figsize=(12, 3))
plt.plot(result["Date"], residuals)
plt.title("Residuals over time (original scale)")
plt.xlabel("Date")
plt.ylabel("y_true - y_pred")
plt.tight_layout()
plt.show()

plt.figure(figsize=(5, 4))
plt.hist(residuals, bins=30)
plt.title("Residual distribution (original scale)")
plt.tight_layout()
plt.show()

# %%
print(f"\n✅ 최적 seq_len = {best_seq_len}, best val_loss = {best_val_loss:.6f}")
# Out:
# ✅ 최적 seq_len = 1, best val_loss = 0.005063

# %%
# 7-1. 학습 곡선 시각화 (Loss / MAE)
print(history.history.keys())

# 1) Loss (train vs val)
plt.figure(figsize=(8, 4))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.tight_layout()
plt.show()

# 2) MAE (train vs val)
if "mae" in history.history and "val_mae" in history.history:
    plt.figure(figsize=(8, 4))
    plt.plot(history.history["mae"], label="Train MAE")
    plt.plot(history.history["val_mae"], label="Val MAE")
    plt.title("Training & Validation MAE")
    plt.xlabel("Epoch")
    plt.ylabel("MAE")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# dict_keys(['loss', 'mae', 'val_loss', 'val_mae'])

# %%
# 12. 예측 수익률 → 예측 S&P500 지수로 변환

# S&P500 지수
price_col = "y_target_log"

# test 구간 길이
n_test = len(y_test_inv)

# y_test / pred가 대응하는 원본 인덱스 범위
start_idx = SEQ_LEN + train_size + val_size
idx_curr_start = start_idx
idx_curr_end   = start_idx + n_test

# 1) 실제 S&P500 지수 (오늘 기준 P_t)
price_true = df[price_col].iloc[idx_curr_start:idx_curr_end].to_numpy()

# 2) 수익률 기준이 되는 "어제 지수" P_{t-1}
price_prev = df[price_col].iloc[idx_curr_start-1:idx_curr_start-1 + n_test].to_numpy()

# 3) 예측/실제 수익률 (디스케일링된 값)
ret_true = y_test_inv.flatten()
ret_pred = pred_inv.flatten()

# 4) 수익률 → 지수로 복원
price_pred_from_ret = price_prev + ret_pred 
price_true_from_ret = price_prev + ret_true 

# 5) 결과 DataFrame (날짜 + 실제 지수 + 예측 지수)
result_price = pd.DataFrame({
    "Date": date_test.reset_index(drop=True),
    "Price_true_df": price_true,
    "Price_true_from_ret": price_true_from_ret,  
    "Price_pred": price_pred_from_ret 
})

print(result_price.head())

# 6) 지수 기준 RMSE / MAE / R^2
rmse_price = np.sqrt(mean_squared_error(result_price["Price_true_df"], result_price["Price_pred"]))
mae_price  = mean_absolute_error(result_price["Price_true_df"], result_price["Price_pred"])
r2_price   = r2_score(result_price["Price_true_df"], result_price["Price_pred"])

print(f"Price RMSE : {rmse_price:.4f}")
print(f"Price MAE  : {mae_price:.4f}")
print(f"Price R^2  : {r2_price:.4f}")

# 7) 그래프: 실제 S&P500 지수 vs 예측 S&P500 지수
plt.figure(figsize=(12, 4))
plt.plot(result_price["Date"], result_price["Price_true_df"], label="True Index", linewidth=2)
plt.plot(result_price["Date"], result_price["Price_pred"], label="Predicted Index", alpha=0.7)
plt.title("S&P500 Index Level: True vs Predicted (from ret_prev)")
plt.xlabel("Date")
plt.ylabel("Index Level (e.g., S&P500)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#         Date  Price_true_df  Price_true_from_ret  Price_pred
# 0 2025-04-04       6.285439             6.275649    6.335758
# 1 2025-04-07       6.225113             6.283657    6.285742
# 2 2025-04-08       6.223330             6.209326    6.225078
# 3 2025-04-09       6.207543             6.323193    6.225193
# 4 2025-04-10       6.307406             6.162735    6.231363
# Price RMSE : 0.0131
# Price MAE  : 0.0077
# Price R^2  : 0.9703

# %%
# 8. 지표(RMSE, MAE, R^2) CSV로 저장 (행/열 반전 버전)
metrics_df = pd.DataFrame({
    "SPY_GRU_RMSE": [rmse_price],
    "SPY_GRU_MAE" : [mae_price],
    "SPY_GRU_R2":   [r2_price]
})

output_path = "../../modeling/성능지표/SPY_GRU_지표.CSV"

metrics_df.to_csv(output_path, index=False, encoding="utf-8-sig")
print(f"지표 저장 완료: {output_path}")
# Out:
# 지표 저장 완료: ../../modeling/성능지표/SPY_GRU_지표.CSV

# %%
# 9. 최종 GRU 모델 저장

import os

save_dir = "../../modeling/Model" 
os.makedirs(save_dir, exist_ok=True)

model_path = os.path.join(save_dir, f"gru_seq{SEQ_LEN}_best.keras")
model.save(model_path)

print(f"✅ 최종 모델 저장 완료: {model_path}")
# Out:
# ✅ 최종 모델 저장 완료: ../../modeling/Model\gru_seq1_best.keras
